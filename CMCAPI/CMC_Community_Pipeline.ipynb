# %%
data ="""
BTC logo
Bitcoin

BTC

$43,486.82
0.72%	0.19%	3.74%	
$851,438,212,959

$13,919,439,620

318,385 BTC

19,579,131 BTC

bitcoin-7d-price-graph
2

ETH logo
Ethereum

ETH

$2,282.14
1.06%	0.28%	3.09%	
$274,276,251,354

$8,496,917,857

3,686,661 ETH

120,183,779 ETH

ethereum-7d-price-graph
3

SOL logo
Solana

SOL

$111.99
1.46%	17.66%	53.10%	
$47,874,742,891

$5,333,226,570

46,377,293 SOL

427,476,141 SOL

solana-7d-price-graph
5

BNB logo
BNB

BNB

$269.27
0.52%	0.63%	11.01%	
$40,627,421,538

$704,035,876

2,614,629 BNB

151,693,920 BNB

bnb-7d-price-graph
6

XRP logo
XRP

XRP

$0.6196
0.44%	0.63%	0.00%	
$33,242,865,408

$778,395,578

1,256,357,524 XRP

54,065,019,376 XRP

xrp-7d-price-graph
7

ADA logo
Cardano

ADA

$0.6221
0.57%	3.18%	2.06%	
$21,628,201,297

$539,485,657

867,186,849 ADA

35,347,973,443 ADA

cardano-7d-price-graph
9

AVAX logo
Avalanche

AVAX

$47.28
2.10%	6.27%	10.88%	
$17,144,753,563

$1,636,011,557

33,650,852 AVAX

365,436,057 AVAX

avalanche-7d-price-graph
10

DOGE logo
Dogecoin

DOGE

$0.0941
0.29%	1.16%	1.72%	
$13,249,778,196

$349,152,552

3,710,254,270 DOGE

142,360,896,384 DOGE

dogecoin-7d-price-graph
11

DOT logo
Polkadot

DOT

$8.63
0.86%	11.93%	21.18%	
$10,731,499,749

$684,050,341

79,305,683 DOT

1,304,773,775 DOT

polkadot-new-7d-price-graph
12

TRX logo
TRON

TRX

$0.1067
0.21%	2.19%	3.86%	
$9,374,713,359

$201,758,249

1,890,957,719 TRX

88,364,387,727 TRX

tron-7d-price-graph
13

LINK logo
Chainlink

LINK

$15.63
0.66%	3.73%	9.62%	
$8,801,640,796

$582,465,774

37,259,562 LINK

568,099,970 LINK

chainlink-7d-price-graph
14

MATIC logo
Polygon

MATIC

$0.8585
0.45%	2.14%	1.52%	
$8,068,320,769

$415,550,920

484,049,687 MATIC

9,555,303,201 MATIC

polygon-7d-price-graph
15

TON logo
Toncoin

TON

$2.22
0.37%	0.96%	1.11%	
$7,622,120,347

$45,614,477

20,554,439 TON

3,455,461,315 TON

toncoin-7d-price-graph
16

SHIB logo
Shiba Inu

SHIB

$0.00001085
1.67%	0.64%	0.31%	
$6,389,530,648

$258,824,991

23,527,689,231,376 SHIB

589,300,690,969,834 SHIB

shiba-inu-7d-price-graph
17

LTC logo
Litecoin

LTC

$72.23
0.66%	0.09%	0.09%	
$5,344,603,653

$282,922,799

3,880,015 LTC

74,012,152 LTC

litecoin-7d-price-graph
18

BCH logo
Bitcoin Cash

BCH

$231.58
0.81%	0.79%	1.75%	
$4,534,372,486

$177,296,865

759,347 BCH

19,594,044 BCH

bitcoin-cash-7d-price-graph
20

ICP logo
Internet Computer

ICP

$9.52
0.67%	4.84%	9.38%	
$4,296,718,250

$133,873,394

13,753,795 ICP

453,422,723 ICP

internet-computer-7d-price-graph
21

ATOM logo
Cosmos

ATOM

$11.34
1.69%	1.43%	0.09%	
$4,306,187,583

$184,963,704

16,082,486 ATOM

380,092,567 ATOM

cosmos-7d-price-graph
22

UNI logo
Uniswap

UNI

$6.52
1.24%	5.19%	6.39%	
$3,901,199,186

$201,104,823

30,393,451 UNI

598,187,016 UNI

uniswap-7d-price-graph
23

NEAR logo
NEAR Protocol

NEAR

$3.88
1.19%	18.18%	62.06%	
$3,853,720,603

$604,463,635

154,853,127 NEAR

1,004,666,471 NEAR

near-protocol-7d-price-graph
24

INJ logo
Injective

INJ

$43.44
1.08%	7.38%	49.98%	
$3,619,266,735

$423,836,061

9,544,820 INJ

83,755,556 INJ

injective-7d-price-graph
25

LEO logo
UNUS SED LEO

LEO

$3.95
0.18%	3.89%	4.65%	
$3,672,571,946

$1,290,024

325,876 LEO

928,131,466 LEO

unus-sed-leo-7d-price-graph
26

XLM logo
Stellar

XLM

$0.1261
0.50%	1.18%	1.62%	
$3,562,617,555

$66,037,044

522,166,268 XLM

28,240,110,133 XLM

stellar-7d-price-graph
27

OP logo
Optimism

OP

$3.64
0.59%	12.57%	70.31%	
$3,309,502,513

$728,528,953

195,647,204 OP

911,294,948 OP

optimism-ethereum-7d-price-graph
28

OKB logo
OKB

OKB

$55.68
0.02%	0.17%	3.25%	
$3,348,342,854

$6,674,917

120,428 OKB

60,000,000 OKB

okb-7d-price-graph
29

IMX logo
Immutable

IMX

$2.48
1.95%	1.95%	21.49%	
$3,207,532,017

$217,127,214

85,841,557 IMX

1,296,459,367 IMX

immutable-x-7d-price-graph
30

XMR logo
Monero

XMR

$176.71
1.13%	0.64%	4.99%	
$3,244,310,762

$81,479,848

456,940 XMR

18,375,027 XMR

monero-7d-price-graph
31

HBAR logo
Hedera

HBAR

$0.09206
1.45%	4.73%	16.98%	
$3,091,328,786

$81,628,627

870,348,851 HBAR

33,612,614,663 HBAR

hedera-7d-price-graph
32

ETC logo
Ethereum Classic

ETC

$21.22
1.31%	0.75%	4.77%	
$3,068,109,240

$177,010,020

8,251,323 ETC

144,678,246 ETC

ethereum-classic-7d-price-graph
33

APT logo
Aptos

APT

$9.42
0.54%	0.77%	16.44%	
$2,863,935,820

$285,127,026

29,862,087 APT

306,201,932 APT

aptos-7d-price-graph
34

FIL logo
Filecoin

FIL

$5.49
1.44%	2.32%	0.56%	
$2,656,259,020

$175,127,897

31,479,243 FIL

484,958,708 FIL

filecoin-7d-price-graph
35

VET logo
VeChain

VET

$0.03502
1.29%	0.65%	19.04%	
$2,542,454,427

$52,756,783

1,488,764,714 VET

72,714,516,834 VET

vechain-7d-price-graph
36

CRO logo
Cronos

CRO

$0.09914
1.03%	1.57%	0.62%	
$2,504,454,655

$10,505,070

104,793,912 CRO

25,263,013,692 CRO

cronos-7d-price-graph
37

KAS logo
Kaspa

KAS

$0.1101
0.76%	1.34%	1.10%	
$2,429,747,726

$32,542,680

294,307,863 KAS

22,040,328,836 KAS

kaspa-7d-price-graph
38

LDO logo
Lido DAO

LDO

$2.40
0.15%	3.01%	13.81%	
$2,145,359,213

$88,678,337

36,640,887 LDO

889,527,612 LDO

lido-dao-7d-price-graph
40

STX logo
Stacks

STX

$1.44
0.27%	0.98%	42.86%	
$2,061,545,825

$247,118,243

170,876,369 STX

1,429,150,347 STX

stacks-7d-price-graph
41

TIA logo
Celestia

TIA

$13.10
2.44%	8.39%	3.05%	
$2,010,393,542

$223,657,463

16,572,478 TIA

152,659,966 TIA

celestia-7d-price-graph
42

RUNE logo
THORChain

RUNE

$5.91
1.73%	12.83%	5.62%	
$2,008,008,402

$324,519,129

54,498,096 RUNE

337,389,343 RUNE

thorchain-7d-price-graph
43

MNT logo
Mantle

MNT

$0.6132
1.03%	4.46%	6.02%	
$1,919,257,193

$81,475,551

131,634,803 MNT

3,130,673,946 MNT

mantle-7d-price-graph
44

ALGO logo
Algorand

ALGO

$0.2389
2.34%	2.98%	21.60%	
$1,909,995,979

$128,655,494

531,487,112 ALGO

8,004,837,224 ALGO

algorand-7d-price-graph
45

EGLD logo
MultiversX

EGLD

$73.22
0.59%	15.82%	15.16%	
$1,924,513,770

$208,309,985

2,861,147 EGLD

26,363,261 EGLD

multiversx-egld-7d-price-graph
46

ARB logo
Arbitrum

ARB

$1.41
0.71%	5.83%	27.27%	
$1,794,308,887

$783,781,628

546,733,786 ARB

1,275,000,000 ARB

arbitrum-7d-price-graph
47

RNDR logo
Render

RNDR

$4.71
0.89%	7.18%	10.53%	
$1,752,590,837

$196,488,320

41,370,334 RNDR

371,908,453 RNDR

render-7d-price-graph
49

GRT logo
The Graph

GRT

$0.1787
0.92%	0.28%	11.70%	
$1,676,126,227

$97,557,969

540,504,786 GRT

9,361,523,383 GRT

the-graph-7d-price-graph
50

AAVE logo
Aave

AAVE

$100.87
0.31%	3.18%	2.49%	
$1,479,136,973

$162,351,552

1,600,790 AAVE

14,673,301 AAVE

aave-7d-price-graph
51

FTM logo
Fantom

FTM

$0.5122
3.33%	4.27%	22.34%	
$1,428,047,249

$186,547,265

355,352,818 FTM

2,803,634,836 FTM

fantom-7d-price-graph
52

FLOW logo
Flow

FLOW

$0.9243
1.00%	2.80%	18.67%	
$1,364,232,781

$74,490,559

79,001,899 FLOW

1,478,118,922 FLOW

flow-7d-price-graph
53

QNT logo
Quant

QNT

$113.79
0.38%	0.55%	2.77%	
$1,373,399,701

$18,639,121

162,663 QNT

12,072,738 QNT

quant-7d-price-graph
54

1000SATS logo
SATS

1000SATS

$0.0006418
1.22%	4.10%	20.05%	
$1,330,429,599

$85,362,481

130,479,902,569 1000SATS

2,100,000,000,000 1000SATS

sats-7d-price-graph
55

HNT logo
Helium

HNT

$7.77
6.71%	21.63%	14.46%	
$1,236,290,592

$35,351,514

4,225,210 HNT

159,172,381 HNT

helium-7d-price-graph
56

MKR logo
Maker

MKR

$1,402.69
0.08%	3.26%	5.71%	
$1,288,510,215

$55,935,847

39,878 MKR

918,885 MKR

maker-7d-price-graph
57

FTT logo
FTX Token

FTT

$3.77
0.78%	5.63%	4.95%	
$1,241,555,767

$63,277,483

16,689,892 FTT

328,895,104 FTT

ftx-token-7d-price-graph
58

SNX logo
Synthetix

SNX

$4.11
0.25%	2.11%	3.74%	
$1,236,898,786

$63,016,226

15,259,948 SNX

301,025,804 SNX

synthetix-7d-price-graph
59

THETA logo
Theta Network

THETA

$1.16
1.16%	3.10%	7.57%	
$1,160,633,183

$21,980,449

18,718,074 THETA

1,000,000,000 THETA

theta-network-7d-price-graph
60

BONK logo
Bonk

BONK

$0.00001884
1.95%	3.35%	11.00%	
$1,146,210,920

$225,186,192

11,683,273,837,151 BONK

60,837,624,528,359 BONK

bonk1-7d-price-graph
61

MINA logo
Mina

MINA

$1.16
1.74%	28.53%	52.71%	
$1,186,662,020

$278,930,962

243,843,919 MINA

1,022,929,210 MINA

mina-7d-price-graph
62

WEMIX logo
WEMIX

WEMIX

$3.29
0.27%	1.37%	3.99%	
$1,144,118,403

$36,307,904

11,010,742 WEMIX

347,805,417 WEMIX

wemix-7d-price-graph
63

SAND logo
The Sandbox

SAND

$0.5328
1.21%	0.81%	3.33%	
$1,128,781,691

$101,450,378

187,995,011 SAND

2,118,731,926 SAND

the-sandbox-7d-price-graph
64

ORDI logo
ORDI

ORDI

$53.40
0.79%	7.92%	6.11%	
$1,121,495,071

$256,858,597

4,726,222 ORDI

21,000,000 ORDI

ordi-7d-price-graph
65

BTT logo
BitTorrent (New)

BTT

$0.000001127
0.24%	0.82%	8.74%	
$1,072,381,847

$37,835,830

33,364,001,048,683 BTT

951,421,714,286,000 BTT

bittorrent-new-7d-price-graph
66

AXS logo
Axie Infinity

AXS

"""

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from json.decoder import JSONDecodeError
import pandas as pd
from datetime import datetime
import time

# %%
lines = data.split('\n')

crypto_data = []

for i in range(len(lines)):
    if 'logo' in lines[i]:  # 'logo'가 포함된 줄을 찾음
        name = lines[i+1].strip()  # logo 바로 위 줄이 암호화폐 이름
        ticker = lines[i+3].strip()  # logo 바로 아래 줄이 티커
        crypto_data.append({'Name': name, 'Ticker': ticker})

# 리스트를 데이터프레임으로 변환
        

crypto_df = pd.DataFrame(crypto_data)

# 결과 출력
print(crypto_df)
# Out:
#                 Name Ticker
# 0            Bitcoin    BTC
# 1           Ethereum    ETH
# 2             Solana    SOL
# 3                BNB    BNB
# 4                XRP    XRP
# ..               ...    ...
# 56             WEMIX  WEMIX
# 57       The Sandbox   SAND
# 58              ORDI   ORDI
# 59  BitTorrent (New)    BTT
# 60     Axie Infinity    AXS
#
# [61 rows x 2 columns]

# %%
# 필터링
filtered_df = crypto_df[~crypto_df['Ticker'].isin(['XLM','VEX','SHIB','OP','OKB','LTC','LEO','KAS','IMX','HBAR','FIL','ETC','CRO','APT','INJ','TON','NEAR','ATOM','MATIC','LTC','ICP','BCH','TRX','LINK','DOGE','AVAX','ADA','BTC','BNB', 'ETH', 'SOL', 'DOT', 'FTT', 'UNI', 'XRP'])]

# 고유한 티커들의 목록 얻기
unique_tickers = filtered_df['Ticker'].unique()

# %%
url = 'https://pro-api.coinmarketcap.com/v1/content/posts/latest'
              
headers = {
  'Accepts': 'application/json',
  'CMC_PRO_API_KEY': 'your api key',
}

session = Session()
session.headers.update(headers)

# %%
last_score = None
all_data = []
batch_size = 10000  # 한 번에 저장할 데이터의 양
file_count = 1  # 파일 카운트
final_count = 0
retry_count = 0
last_score_previous = None
same_score_count = 0
max_same_score_count = 3 # 임계값 설정
max_count = 0
for ticker in unique_tickers:
    try:
        while True:
            parameters = {
                'symbol': ticker,
                'last_score': last_score,
                'CMC_PRO_API_KEY': 'your api key'
            }
            try : 
                response = session.get(url, params=parameters)
                data = json.loads(response.text)
                if 'data' not in data or not data['data']['list']:
                    print("빈 데이터를 받았거나 API 요청 제한에 도달했습니다. 재시도합니다.")
                    retry_count += 1

                    if retry_count >= 30:  # 5번 재시도 후에도 데이터가 없다면 last_score를 증가
                        print("재시도 횟수 초과. last_score를 증가시킵니다.")
                        last_score = int(last_score)
                        last_score += 100000
                        last_score = str(last_score)
                        final_count += 1
                        retry_count = 0  # 재시도 카운트 초기화
                


                    if final_count >= 5:
                        if all_data:
                            df = pd.DataFrame(all_data)[['text_content', 'post_time']]
                            df['post_time'] = pd.to_datetime(df['post_time'].astype(int), unit='ms')
                            df['date'] = df['post_time'].dt.date
                            del df['post_time']
                            df.to_csv(f'{ticker}_data_{file_count}.csv', index=False)
                        print("50번의 재시도 후에도 빈 데이터를 계속 받아 종료합니다.")
                        last_score = None
                        file_count = 1
                        final_count = 0
                        break
                    # 다음 반복으로 넘어감

                    time.sleep(10)  # 10초 동안 대기
                    continue


        
                posts_list = data['data']['list']
        
                all_data.extend(posts_list)
                same_score_count = 0 
            
                retry_count = 0
            # 일정 양의 데이터가 쌓이면 CSV로 저장
                if len(all_data) >= batch_size:
                    df = pd.DataFrame(all_data)[['text_content', 'post_time']]
                    df['post_time'] = pd.to_datetime(df['post_time'].astype(int), unit='ms')
                    df['date'] = df['post_time'].dt.date
                    del df['post_time']
                    df.to_csv(f'{ticker}_data_{file_count}.csv', index=False)
                    file_count += 1

                # 저장된 데이터 제거
                    all_data = all_data[batch_size:]
                print(posts_list[-1]['post_time'])
                #새로운 last_score 업데이트
                last_score = posts_list[-1]['post_time']

                if last_score == last_score_previous:
                    same_score_count += 1
                    if same_score_count >= max_same_score_count:
                        print("동일한 last_score로 인한 반복 횟수 초과. 다음 티커로 넘어갑니다.")
                        last_score_previous = None
                        break
                        
                        
                last_score_previous = last_score
            except JSONDecodeError:
                print("JSONDecodeError 발생. 10초 후에 재시도합니다.")
                time.sleep(10)  # 10초 대기
                continue  # while 루프의 시작부분으로 돌아감

    except (ConnectionError, Timeout, TooManyRedirects) as e:
        print(e)

# 남아 있는 데이터를 CSV 파일로 저장
